# %% [markdown]
# H1 : Lighting is preattentive.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pingouin as pg

# %%
df = pd.read_csv("logs_participant_5.csv")
df
# Out:
#       DesignName  ParticipantID  TrialID  Block1  Block2                DT  \
# 0    Touchstone2              1        0       1       1          lighting
# 1    Touchstone2              1        1       3       2  ContrastLighting
# 2    Touchstone2              1        2       1       1          lighting
# 3    Touchstone2              1        3       2       1          Contrast
# 4    Touchstone2              1        4       3       1  ContrastLighting
# ..           ...            ...      ...     ...     ...               ...
# 319  Touchstone2              6       49       1       1          Contrast
# 320  Touchstone2              6       50       3       1          lighting
# 321  Touchstone2              6       51       2       1  ContrastLighting
# 322  Touchstone2              6       52       3       3          lighting
# 323  Touchstone2              6       53       3       3          lighting
#
#          OC  visualSearchTime  ErrorCount
# 0    medium              7795           0
# 1       low              4322           0
# 2    medium              2781           0
# 3    medium              1895           0
# 4    medium              4122           0
# ..      ...               ...         ...
# 319     low              1325           0
# 320     low              1384           0
# 321     low              2843           0
# 322  medium              1721           0
# 323  medium              2181           0
#
# [324 rows x 9 columns]

# %%
df_lighting = df[df['DT'] == 'lighting']
df_lighting
# Out:
#       DesignName  ParticipantID  TrialID  Block1  Block2        DT      OC  \
# 0    Touchstone2              1        0       1       1  lighting  medium
# 2    Touchstone2              1        2       1       1  lighting  medium
# 11   Touchstone2              1       11       1       1  lighting  medium
# 13   Touchstone2              1       13       1       3  lighting    high
# 15   Touchstone2              1       15       1       2  lighting     low
# ..           ...            ...      ...     ...     ...       ...     ...
# 313  Touchstone2              6       43       3       3  lighting  medium
# 315  Touchstone2              6       45       3       2  lighting    high
# 320  Touchstone2              6       50       3       1  lighting     low
# 322  Touchstone2              6       52       3       3  lighting  medium
# 323  Touchstone2              6       53       3       3  lighting  medium
#
#      visualSearchTime  ErrorCount
# 0                7795           0
# 2                2781           0
# 11               2152           0
# 13               6862           0
# 15               2228           0
# ..                ...         ...
# 313              2239           0
# 315              1811           0
# 320              1384           0
# 322              1721           0
# 323              2181           0
#
# [108 rows x 9 columns]

# %%
df_Constrast = df[df['DT'] == 'Contrast']
df_Constrast
# Out:
#       DesignName  ParticipantID  TrialID  Block1  Block2        DT      OC  \
# 3    Touchstone2              1        3       2       1  Contrast  medium
# 5    Touchstone2              1        5       2       3  Contrast    high
# 6    Touchstone2              1        6       2       1  Contrast  medium
# 8    Touchstone2              1        8       2       1  Contrast  medium
# 9    Touchstone2              1        9       2       3  Contrast    high
# ..           ...            ...      ...     ...     ...       ...     ...
# 307  Touchstone2              6       37       1       1  Contrast     low
# 309  Touchstone2              6       39       1       1  Contrast     low
# 312  Touchstone2              6       42       1       2  Contrast    high
# 316  Touchstone2              6       46       1       3  Contrast  medium
# 319  Touchstone2              6       49       1       1  Contrast     low
#
#      visualSearchTime  ErrorCount
# 3                1895           0
# 5                3054           0
# 6                2039           0
# 8                1859           0
# 9                2611           0
# ..                ...         ...
# 307              1178           0
# 309              1886           0
# 312              2744           0
# 316              1237           0
# 319              1325           0
#
# [108 rows x 9 columns]

# %%
df_ConstrastLighting = df[df['DT'] == 'ContrastLighting']
df_ConstrastLighting
# Out:
#       DesignName  ParticipantID  TrialID  Block1  Block2                DT  \
# 1    Touchstone2              1        1       3       2  ContrastLighting
# 4    Touchstone2              1        4       3       1  ContrastLighting
# 7    Touchstone2              1        7       3       3  ContrastLighting
# 14   Touchstone2              1       14       3       3  ContrastLighting
# 16   Touchstone2              1       16       3       3  ContrastLighting
# ..           ...            ...      ...     ...     ...               ...
# 311  Touchstone2              6       41       2       3  ContrastLighting
# 314  Touchstone2              6       44       2       1  ContrastLighting
# 317  Touchstone2              6       47       2       2  ContrastLighting
# 318  Touchstone2              6       48       2       1  ContrastLighting
# 321  Touchstone2              6       51       2       1  ContrastLighting
#
#          OC  visualSearchTime  ErrorCount
# 1       low              4322           0
# 4    medium              4122           0
# 7      high              2307           0
# 14     high              5102           1
# 16     high              2574           0
# ..      ...               ...         ...
# 311  medium              1870           0
# 314     low              2123           0
# 317    high              3296           0
# 318     low              3269           0
# 321     low              2843           0
#
# [108 rows x 9 columns]
